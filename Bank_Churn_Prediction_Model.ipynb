# %% [markdown]
# <center><font size=6> Bank Churn Prediction </font></center>

# %% [markdown]
# ## Problem Statement

# %% [markdown]
# ### Context

# %% [markdown]
# Businesses like banks which provide service have to worry about problem of 'Customer Churn' i.e. customers leaving and joining another service provider. It is important to understand which aspects of the service influence a customer's decision in this regard. Management can concentrate efforts on improvement of service, keeping in mind these priorities.

# %% [markdown]
# ### Objective

# %% [markdown]
# You as a Data scientist with the  bank need to  build a neural network based classifier that can determine whether a customer will leave the bank  or not in the next 6 months.

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# * CustomerId: Unique ID which is assigned to each customer
#
# * Surname: Last name of the customer
#
# * CreditScore: It defines the credit history of the customer.
#
# * Geography: A customer’s location
#
# * Gender: It defines the Gender of the customer
#
# * Age: Age of the customer
#
# * Tenure: Number of years for which the customer has been with the bank
#
# * NumOfProducts: refers to the number of products that a customer has purchased through the bank.
#
# * Balance: Account balance
#
# * HasCrCard: It is a categorical variable which decides whether the customer has credit card or not.
#
# * EstimatedSalary: Estimated salary
#
# * IsActiveMember: Is is a categorical variable which decides whether the customer is active member of the bank or not ( Active member in the sense, using bank products regularly, making transactions etc )
#
# * Exited : whether or not the customer left the bank within six month. It can take two values
#     - 0 = No ( Customer did not leave the bank )
#     - 1 = Yes ( Customer left the bank )

# %% [markdown]
# ## Importing necessary libraries

# %%
# Installing the libraries with the specified version.
# !pip install tensorflow==2.15.0 scikit-learn==1.2.2 seaborn==0.13.1 matplotlib==3.7.1 numpy==1.25.2 pandas==2.0.3 imbalanced-learn==0.10.1 -q --user
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 475.2/475.2 MB 3.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.6/9.6 MB 64.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 294.8/294.8 kB 13.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 59.1 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.2/18.2 MB 22.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.3/12.3 MB 52.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 226.0/226.0 kB 18.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.7/1.7 MB 53.8 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 42.9 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 66.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 442.0/442.0 kB 28.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.9/77.9 kB 6.1 MB/s eta 0:00:00
#   WARNING: The scripts f2py, f2py3 and f2py3.10 are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The script tensorboard is installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
#   WARNING: The scripts estimator_ckpt_converter, import_pb_to_tensorboard, saved_model_cli, tensorboard, tf_upgrade_v2, tflite_convert, toco and toco_from_protos are installed in '/root/.local/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-colab 1.0.0 requires pandas==2.2.2, but you have pandas 2.0.3 which is incompatible.
# mizani 0.13.0 requires pandas>=2.2.0, but you have pandas 2.0.3 which is incompatible.
# mlxtend 0.23.3 requires scikit-learn>=1.3.1, but you have scikit-learn 1.2.2 which is incompatible.
# plotnine 0.14.1 requires matplotlib>=3.8.0, but you have matplotlib 3.7.1 which is incompatible.
# plotnine 0.14.1 requires pandas>=2.2.0, but you have pandas 2.0.3 which is incompatible.
# tensorstore 0.1.68 requires ml-dtypes>=0.3.1, but you have ml-dtypes 0.2.0 which is incompatible.
# tf-keras 2.17.0 requires tensorflow<2.18,>=2.17, but you have tensorflow 2.15.0 which is incompatible.
# xarray 2024.10.0 requires pandas>=2.1, but you have pandas 2.0.3 which is incompatible.

# %% [markdown]
# **Note:** After running the above cell, please restart the notebook kernel/runtime (depending on whether you're using Jupyter Notebook or Google Colab) and then sequentially run all cells from the one below.

# %%
# Libraries to help with reading and manipulating data
import pandas as pd
import numpy as np

# libaries to help with data visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Library to split data
from sklearn.model_selection import train_test_split

# library to import to standardize the data
from sklearn.preprocessing import StandardScaler, LabelEncoder

# importing different functions to build models
import tensorflow as tf
from tensorflow import keras
from keras import backend
from keras.models import Sequential
from keras.layers import Dense, Dropout

# importing SMOTE
from imblearn.over_sampling import SMOTE

# importing metrics
from sklearn.metrics import confusion_matrix,roc_curve,classification_report,recall_score

import random

# Library to avoid the warnings
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Loading the dataset

# %%
# uncomment and run the following lines in case Colab is being used
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
ds = pd.read_csv("/content/drive/MyDrive/Churn.csv")    # complete the code to load the dataset

# %% [markdown]
# ## Data Overview

# %% [markdown]
# ### View the first and last 5 rows of the dataset.

# %%
# let's view the first 5 rows of the data
ds.head() ##  Complete the code to view top 5 rows of the data
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2       0.00              1          1               1
# 1       1   83807.86              1          0               1
# 2       8  159660.80              3          1               0
# 3       1       0.00              2          0               0
# 4       2  125510.82              1          1               1
#
#    EstimatedSalary  Exited
# 0        101348.88       1
# 1        112542.58       0
# 2        113931.57       1
# 3         93826.63       0
# 4         79084.10       0

# %%
# let's view the last 5 rows of the data
ds.tail() ##  Complete the code to view last 5 rows of the data
# Out:
#       RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 9995       9996    15606229   Obijiaku          771    France    Male   39
# 9996       9997    15569892  Johnstone          516    France    Male   35
# 9997       9998    15584532        Liu          709    France  Female   36
# 9998       9999    15682355  Sabbatini          772   Germany    Male   42
# 9999      10000    15628319     Walker          792    France  Female   28
#
#       Tenure    Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 9995       5       0.00              2          1               0
# 9996      10   57369.61              1          1               1
# 9997       7       0.00              1          0               1
# 9998       3   75075.31              2          1               0
# 9999       4  130142.79              1          1               0
#
#       EstimatedSalary  Exited
# 9995         96270.64       0
# 9996        101699.77       0
# 9997         42085.58       1
# 9998         92888.52       1
# 9999         38190.78       0

# %% [markdown]
# ### Understand the shape of the dataset

# %%
# Checking the number of rows and columns in the training data
ds.shape ##  Complete the code to view dimensions of the train data
# Out:
# (10000, 14)

# %% [markdown]
# ### Check the data types of the columns for the dataset

# %%
ds.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           10000 non-null  int64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(2), int64(9), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# ### Checking the Statistical Summary

# %%
ds.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure           10000.0  5.012800e+00      2.892174         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
# Exited           10000.0  2.037000e-01      0.402769         0.00
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# CreditScore           584.00  6.520000e+02  7.180000e+02       850.00
# Age                    32.00  3.700000e+01  4.400000e+01        92.00
# Tenure                  3.00  5.000000e+00  7.000000e+00        10.00
# Balance                 0.00  9.719854e+04  1.276442e+05    250898.09
# NumOfProducts           1.00  1.000000e+00  2.000000e+00         4.00
# HasCrCard               0.00  1.000000e+00  1.000000e+00         1.00
# IsActiveMember          0.00  1.000000e+00  1.000000e+00         1.00
# EstimatedSalary     51002.11  1.001939e+05  1.493882e+05    199992.48
# Exited                  0.00  0.000000e+00  0.000000e+00         1.00

# %% [markdown]
# ### Checking for Missing Values

# %%
# let's check for missing values in the data
ds.isna().sum() ##  Complete the code to check missing entries in the train data
# Out:
# RowNumber          0
# CustomerId         0
# Surname            0
# CreditScore        0
# Geography          0
# Gender             0
# Age                0
# Tenure             0
# Balance            0
# NumOfProducts      0
# HasCrCard          0
# IsActiveMember     0
# EstimatedSalary    0
# Exited             0
# dtype: int64

# %% [markdown]
# ### Checking for unique values for each of the column

# %%
ds.nunique()
# Out:
# RowNumber          10000
# CustomerId         10000
# Surname             2932
# CreditScore          460
# Geography              3
# Gender                 2
# Age                   70
# Tenure                11
# Balance             6382
# NumOfProducts          4
# HasCrCard              2
# IsActiveMember         2
# EstimatedSalary     9999
# Exited                 2
# dtype: int64

# %%
#RowNumber , CustomerId and Surname are unique hence dropping it
ds = ds.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %% [markdown]
# ## Exploratory Data Analysis

# %% [markdown]
# ### Univariate Analysis

# %%
# function to plot a boxplot and a histogram along the same scale.


def histogram_boxplot(data, feature, figsize=(12, 7), kde=False, bins=None):
    """
    Boxplot and histogram combined

    data: dataframe
    feature: dataframe column
    figsize: size of figure (default (12,7))
    kde: whether to show the density curve (default False)
    bins: number of bins for histogram (default None)
    """
    f2, (ax_box2, ax_hist2) = plt.subplots(
        nrows=2,  # Number of rows of the subplot grid= 2
        sharex=True,  # x-axis will be shared among all subplots
        gridspec_kw={"height_ratios": (0.25, 0.75)},
        figsize=figsize,
    )  # creating the 2 subplots
    sns.boxplot(
        data=data, x=feature, ax=ax_box2, showmeans=True, color="violet"
    )  # boxplot will be created and a star will indicate the mean value of the column
    sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2, bins=bins, palette="winter"
    ) if bins else sns.histplot(
        data=data, x=feature, kde=kde, ax=ax_hist2
    )  # For histogram
    ax_hist2.axvline(
        data[feature].mean(), color="green", linestyle="--"
    )  # Add mean to the histogram
    ax_hist2.axvline(
        data[feature].median(), color="black", linestyle="-"
    )  # Add median to the histogram

# %%
# function to create labeled barplots


def labeled_barplot(data, feature, perc=False, n=None):
    """
    Barplot with percentage at the top

    data: dataframe
    feature: dataframe column
    perc: whether to display percentages instead of count (default is False)
    n: displays the top n category levels (default is None, i.e., display all levels)
    """

    total = len(data[feature])  # length of the column
    count = data[feature].nunique()
    if n is None:
        plt.figure(figsize=(count + 1, 5))
    else:
        plt.figure(figsize=(n + 1, 5))

    plt.xticks(rotation=90, fontsize=15)
    ax = sns.countplot(
        data=data,
        x=feature,
        palette="Paired",
        order=data[feature].value_counts().index[:n].sort_values(),
    )

    for p in ax.patches:
        if perc == True:
            label = "{:.1f}%".format(
                100 * p.get_height() / total
            )  # percentage of each class of the category
        else:
            label = p.get_height()  # count of each level of the category

        x = p.get_x() + p.get_width() / 2  # width of the plot
        y = p.get_height()  # height of the plot

        ax.annotate(
            label,
            (x, y),
            ha="center",
            va="center",
            size=12,
            xytext=(0, 5),
            textcoords="offset points",
        )  # annotate the percentage

    plt.show()  # show the plot

# %% [markdown]
# #### Observations on CreditScore

# %%
histogram_boxplot(ds,'CreditScore')

# %% [markdown]
# #### Observations on Age

# %%
histogram_boxplot(ds,'Age')          ## Complete the code to create histogram_boxplot for Age

# %% [markdown]
# #### Observations on Balance

# %%
histogram_boxplot(ds,'Balance')          ## Complete the code to create histogram_boxplot for Balance

# %% [markdown]
# #### Observations on Estimated Salary

# %%
histogram_boxplot(ds,'EstimatedSalary')          ## Complete the code to create histogram_boxplot for Estimated Salary

# %% [markdown]
# #### Observations on Exited

# %%
labeled_barplot(ds, "Exited", perc=True)

# %% [markdown]
# #### Observations on Geography

# %%
labeled_barplot(ds,"Geography",perc=True)               ## Complete the code to create labeled_barplot for Geography

# %% [markdown]
# #### Observations on Gender

# %%
labeled_barplot(ds,"Gender",perc=True)               ## Complete the code to create labeled_barplot for Gender

# %% [markdown]
# #### Observations on Tenure

# %%
labeled_barplot(ds,"Tenure",perc=True)               ## Complete the code to create labeled_barplot for Tenure

# %% [markdown]
# #### Observations on Number of Products

# %%
labeled_barplot(ds,"NumOfProducts",perc=True)               ## Complete the code to create labeled_barplot for Number of products

# %% [markdown]
# #### Observations on Has Credit Card

# %%
labeled_barplot(ds,"HasCrCard",perc=True)               ## Complete the code to create labeled_barplot for Has credit card

# %% [markdown]
# #### Observations on Is Active Member

# %%
labeled_barplot(ds,"IsActiveMember",perc=True)               ## Complete the code to create labeled_barplot for Is active member

# %% [markdown]
# ### Bivariate Analysis

# %%
# function to plot stacked bar chart


def stacked_barplot(data, predictor, target):
    """
    Print the category counts and plot a stacked bar chart

    data: dataframe
    predictor: independent variable
    target: target variable
    """
    count = data[predictor].nunique()
    sorter = data[target].value_counts().index[-1]
    tab1 = pd.crosstab(data[predictor], data[target], margins=True).sort_values(
        by=sorter, ascending=False
    )
    print(tab1)
    print("-" * 120)
    tab = pd.crosstab(data[predictor], data[target], normalize="index").sort_values(
        by=sorter, ascending=False
    )
    tab.plot(kind="bar", stacked=True, figsize=(count + 1, 5))
    plt.legend(
        loc="lower left",
        frameon=False,
    )
    plt.legend(loc="upper left", bbox_to_anchor=(1, 1))
    plt.show()

# %% [markdown]
# #### Correlation plot

# %%
# defining the list of numerical columns
cols_list = ["CreditScore","Age","Tenure","Balance","EstimatedSalary"]

# %%
plt.figure(figsize=(15, 7))
sns.heatmap(ds[cols_list].corr(), annot=True, vmin=-1, vmax=1, fmt=".2f", cmap="Spectral")
plt.show()

# %% [markdown]
# #### Exited Vs Geography

# %%
stacked_barplot(ds, "Geography", "Exited" )
# Out:
# Exited        0     1    All
# Geography
# All        7963  2037  10000
# Germany    1695   814   2509
# France     4204   810   5014
# Spain      2064   413   2477
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Gender

# %%
stacked_barplot(ds, "Gender", "Exited")                   ## Complete the code to plot stacked barplot for Exited and Gender
# Out:
# Exited     0     1    All
# Gender
# All     7963  2037  10000
# Female  3404  1139   4543
# Male    4559   898   5457
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Has Credit Card

# %%
stacked_barplot(ds, "HasCrCard", "Exited")                   ## Complete the code to plot stacked barplot for Exited and Has credit card
# Out:
# Exited        0     1    All
# HasCrCard
# All        7963  2037  10000
# 1          5631  1424   7055
# 0          2332   613   2945
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Is active member

# %%
stacked_barplot(ds, "IsActiveMember", "Exited")                   ## Complete the code to plot stacked barplot for Exited and Is active member
# Out:
# Exited             0     1    All
# IsActiveMember
# All             7963  2037  10000
# 0               3547  1302   4849
# 1               4416   735   5151
# ------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# #### Exited Vs Credit Score

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='CreditScore',x='Exited',data=ds)
plt.show()

# %% [markdown]
# #### Exited Vs Age

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Age',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Age
plt.show()

# %% [markdown]
# #### Exited Vs Tenure

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Tenure',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Tenure
plt.show()

# %% [markdown]
# #### Exited Vs Balance

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='Balance',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Balance
plt.show()

# %% [markdown]
# #### Exited Vs Number of Products

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='NumOfProducts',x='Exited',data=ds)               ## Complete the code to plot the boxplot for Exited and Number of products
plt.show()

# %% [markdown]
# #### Exited Vs Estimated Salary

# %%
plt.figure(figsize=(5,5))
sns.boxplot(y='EstimatedSalary',x='Exited',data= ds)               ## Complete the code to plot the boxplot for Exited and Estimated Salary
plt.show()

# %% [markdown]
# ## Data Preprocessing

# %% [markdown]
# ### Dummy Variable Creation

# %%
ds = pd.get_dummies(ds,columns=ds.select_dtypes(include=["object"]).columns.tolist(),drop_first=True,dtype=float)

# %% [markdown]
# ### Train-validation-test Split

# %%
X = ds.drop(['Exited'],axis=1) # Credit Score through Estimated Salary
y = ds['Exited'] # Exited

# %%
# Splitting the dataset into the Training and Testing set.

X_large, X_test, y_large, y_test = train_test_split(X, y, test_size = .15, random_state = 42,stratify=y,shuffle = True) ## Complete the code to Split the X and y and obtain test set

# %%
# Splitting the dataset into the Training and Testing set.

X_train, X_val, y_train, y_val = train_test_split(X_large, y_large, test_size = .17647, random_state = 42,stratify=y_large, shuffle = True) ## complete the code to Split X_large and y_large to obtain train and validation sets

# %%
print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (7000, 11) (1500, 11) (1500, 11)

# %%
print(y_train.shape, y_val.shape, y_test.shape)
# Out:
# (7000,) (1500,) (1500,)

# %% [markdown]
# ### Data Normalization

# %% [markdown]
# Since all the numerical values are on a different scale, so we will be scaling all the numerical values to bring them to the same scale.

# %%
# creating an instance of the standard scaler
sc = StandardScaler()

X_train[cols_list] = sc.fit_transform(X_train[cols_list])
X_val[cols_list] = sc.transform(X_val[cols_list])    ## Complete the code to specify the columns to normalize
X_test[cols_list] = sc.transform(X_test[cols_list])    ## Complete the code to specify the columns to normalize

# %% [markdown]
# ## Model Building

# %% [markdown]
# ### Model Evaluation Criterion

# %% [markdown]
# Write down the logic for choosing the metric that would be the best metric for this business scenario.
#
# -

# %% [markdown]
# **Let's create a function for plotting the confusion matrix**

# %%
def make_confusion_matrix(actual_targets, predicted_targets):
    """
    To plot the confusion_matrix with percentages

    actual_targets: actual target (dependent) variable values
    predicted_targets: predicted target (dependent) variable values
    """
    cm = confusion_matrix(actual_targets, predicted_targets)
    labels = np.asarray(
        [
            ["{0:0.0f}".format(item) + "\n{0:.2%}".format(item / cm.flatten().sum())]
            for item in cm.flatten()
        ]
    ).reshape(cm.shape[0], cm.shape[1])

    plt.figure(figsize=(6, 4))
    sns.heatmap(cm, annot=labels, fmt="")
    plt.ylabel("True label")
    plt.xlabel("Predicted label")

# %% [markdown]
# Let's create two blank dataframes that will store the recall values for all the models we build.

# %%
train_metric_df = pd.DataFrame(columns=["recall"])
valid_metric_df = pd.DataFrame(columns=["recall"])

# %% [markdown]
# ### Neural Network with SGD Optimizer

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_0 = Sequential()
# Adding the input layer with 64 neurons and relu as activation function
model_0.add(Dense(64, activation='relu', input_dim = X_train.shape[1]))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_0.add(Dense(32, activation='relu'))
# Complete the code to add the output layer with the number of neurons required.
model_0.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use SGD as the optimizer.
optimizer = tf.keras.optimizers.SGD(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
## Complete the code to compile the model with binary cross entropy as loss function and recall as the metric.
model_0.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_0.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# Fitting the ANN

history_0 = model_0.fit(
    X_train, y_train,
    batch_size=32,    ## Complete the code to specify the batch size to use
    validation_data=(X_val,y_val),
    epochs=20,    ## Complete the code to specify the number of epochs
    verbose=1
)
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.6295 - recall: 0.1399 - val_loss: 0.5747 - val_recall: 0.0066
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5636 - recall: 0.0016 - val_loss: 0.5371 - val_recall: 0.0000e+00
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5311 - recall: 0.0000e+00 - val_loss: 0.5174 - val_recall: 0.0000e+00
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5138 - recall: 0.0000e+00 - val_loss: 0.5061 - val_recall: 0.0000e+00
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5037 - recall: 0.0000e+00 - val_loss: 0.4988 - val_recall: 0.0000e+00
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4969 - recall: 0.0000e+00 - val_loss: 0.4934 - val_recall: 0.0000e+00
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4919 - recall: 0.0000e+00 - val_loss: 0.4889 - val_recall: 0.0000e+00
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4877 - recall: 0.0000e+00 - val_loss: 0.4851 - val_recall: 0.0000e+00
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4841 - recall: 0.0000e+00 - val_loss: 0.4817 - val_recall: 0.0000e+00
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4808 - recall: 0.0000e+00 - val_loss: 0.4785 - val_recall: 0.0000e+00
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4778 - recall: 0.0000e+00 - val_loss: 0.4756 - val_recall: 0.0000e+00
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4750 - recall: 0.0000e+00 - val_loss: 0.4729 - val_recall: 0.0000e+00
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4724 - recall: 0.0000e+00 - val_loss: 0.4703 - val_recall: 0.0033
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4699 - recall: 0.0000e+00 - val_loss: 0.4679 - val_recall: 0.0033
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4675 - recall: 6.5899e-04 - val_loss: 0.4656 - val_recall: 0.0033
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4653 - recall: 0.0022 - val_loss: 0.4635 - val_recall: 0.0033
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step - loss: 0.4632 - recall: 0.0022 - val_loss: 0.4615 - val_recall: 0.0033
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4612 - recall: 0.0027 - val_loss: 0.4596 - val_recall: 0.0066
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4593 - recall: 0.0034 - val_loss: 0.4579 - val_recall: 0.0066
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4576 - recall: 0.0048 - val_loss: 0.4562 - val_recall: 0.0066

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_0.history['loss'])
plt.plot(history_0.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Recall**

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_0.history['recall'])
plt.plot(history_0.history['val_recall'])
plt.title('model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Predicting the results using best as a threshold
y_train_pred = model_0.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Predicting the results using best as a threshold
y_val_pred = model_0.predict(X_val)    ## Complete the code to make prediction on the validation set
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with SGD"

train_metric_df.loc[model_name] = recall_score(y_train, y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val, y_val_pred)

# %% [markdown]
# **Classification report**

# %%
#lassification report
cr = classification_report(y_train, y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      5574
#            1       0.69      0.01      0.01      1426
#
#     accuracy                           0.80      7000
#    macro avg       0.74      0.50      0.45      7000
# weighted avg       0.78      0.80      0.71      7000

# %%
#classification report
cr=classification_report(y_val, y_val_pred)    ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.80      1.00      0.89      1195
#            1       0.67      0.01      0.01       305
#
#     accuracy                           0.80      1500
#    macro avg       0.73      0.50      0.45      1500
# weighted avg       0.77      0.80      0.71      1500

# %% [markdown]
# **Confusion matrix**

# %%
make_confusion_matrix(y_train, y_train_pred)

# %%
make_confusion_matrix(y_val, y_val_pred)    ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ## Model Performance Improvement

# %% [markdown]
# ### Neural Network with Adam Optimizer

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_1 = Sequential()
#Complete the code to add a input layer (specify the # of neurons and activation function)
model_1.add(Dense(64,activation='relu',input_dim = X_train.shape[1]))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_1.add(Dense(32,activation='relu'))
#Complete the code to add a output layer with the required number of neurons and relu as activation function
model_1.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam()

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_1.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_1.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 64)                  │             768 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 32)                  │           2,080 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │              33 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 2,881 (11.25 KB)
#  Trainable params: 2,881 (11.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Fitting the ANN
history_1 = model_1.fit(
    X_train,y_train,
    batch_size=32, ## Complete the code to specify the batch size to use
    validation_data=(X_val,y_val),
    epochs= 20, ## Complete the code to specify the number of epochs
    verbose=1
)
# Out:
# Epoch 1/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.2839 - recall: 0.5764 - val_loss: 0.3478 - val_recall: 0.5508
# Epoch 2/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2834 - recall: 0.5744 - val_loss: 0.3478 - val_recall: 0.5508
# Epoch 3/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - loss: 0.2828 - recall: 0.5776 - val_loss: 0.3488 - val_recall: 0.5541
# Epoch 4/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.2821 - recall: 0.5777 - val_loss: 0.3488 - val_recall: 0.5541
# Epoch 5/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.2813 - recall: 0.5784 - val_loss: 0.3498 - val_recall: 0.5574
# Epoch 6/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2807 - recall: 0.5796 - val_loss: 0.3501 - val_recall: 0.5574
# Epoch 7/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2801 - recall: 0.5807 - val_loss: 0.3507 - val_recall: 0.5574
# Epoch 8/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2794 - recall: 0.5835 - val_loss: 0.3514 - val_recall: 0.5574
# Epoch 9/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2788 - recall: 0.5842 - val_loss: 0.3520 - val_recall: 0.5574
# Epoch 10/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2781 - recall: 0.5823 - val_loss: 0.3527 - val_recall: 0.5607
# Epoch 11/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2775 - recall: 0.5813 - val_loss: 0.3531 - val_recall: 0.5574
# Epoch 12/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.2770 - recall: 0.5836 - val_loss: 0.3538 - val_recall: 0.5639
# Epoch 13/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2761 - recall: 0.5845 - val_loss: 0.3542 - val_recall: 0.5574
# Epoch 14/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2754 - recall: 0.5820 - val_loss: 0.3550 - val_recall: 0.5607
# Epoch 15/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2748 - recall: 0.5901 - val_loss: 0.3559 - val_recall: 0.5672
# Epoch 16/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2739 - recall: 0.5917 - val_loss: 0.3560 - val_recall: 0.5705
# Epoch 17/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.2733 - recall: 0.5960 - val_loss: 0.3574 - val_recall: 0.5672
# Epoch 18/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2725 - recall: 0.5991 - val_loss: 0.3576 - val_recall: 0.5672
# Epoch 19/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2719 - recall: 0.6087 - val_loss: 0.3582 - val_recall: 0.5672
# Epoch 20/20
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.2711 - recall: 0.6083 - val_loss: 0.3583 - val_recall: 0.5672

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_1.history['loss'])
plt.plot(history_1.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# **Recall**

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_1.history['recall'])
plt.plot(history_1.history['val_recall'])
plt.title('model recall')
plt.ylabel('Recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Predicting the results using 0.5 as the threshold
y_train_pred = model_1.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Predicting the results using 0.5 as the threshold
y_val_pred = model_1.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with Adam"

train_metric_df.loc[model_name] = recall_score(y_train,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
#lassification report
cr=classification_report(y_train,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.96      0.94      5574
#            1       0.80      0.66      0.72      1426
#
#     accuracy                           0.90      7000
#    macro avg       0.86      0.81      0.83      7000
# weighted avg       0.89      0.90      0.89      7000

# %%
#classification report
cr=classification_report(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.89      0.93      0.91      1195
#            1       0.68      0.57      0.62       305
#
#     accuracy                           0.86      1500
#    macro avg       0.79      0.75      0.77      1500
# weighted avg       0.85      0.86      0.85      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ### Neural Network with Adam Optimizer and Dropout

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the neural network
model_2 = Sequential()
#Adding the input layer with 32 neurons and relu as activation function
model_2.add(Dense(32,activation='relu',input_dim = X_train.shape[1]))
# Complete the code to add dropout with ratio of 0.2 or any suitable value.
model_2.add(Dropout(0.2))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_2.add(Dense(16,activation='relu'))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_2.add(Dense(8,activation='relu'))
# Complete the code to add dropout with ratio of 0.1 or any suitable value.
model_2.add(Dropout(0.1))
# Complete the code to add a hidden layer (specify the # of neurons and the activation function)
model_2.add(Dense(4,activation='relu'))
# Complete the code to add the number of neurons required in the output layer.
model_2.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam()

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
## Complete the code to compile the model with binary cross entropy as loss function and recall as the metric.
model_2.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
# Summary of the model
model_2.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_6 (Dense)                      │ (None, 32)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_3 (Dropout)                  │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_7 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_8 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_4 (Dropout)                  │ (None, 8)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_9 (Dense)                      │ (None, 4)                   │              36 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_10 (Dense)                     │ (None, 1)                   │               5 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,089 (4.25 KB)
#  Trainable params: 1,089 (4.25 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Fitting the ANN with batch_size = 32 and 100 epochs
history_2 = model_2.fit(
    X_train,y_train,
    batch_size=32,  ##Complete the code to specify the batch size.
    epochs=80, ##Complete the code to specify the # of epochs.
    verbose=1,
    validation_data=(X_val,y_val)
)
# Out:
# Epoch 1/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.5537 - recall_1: 0.0523 - val_loss: 0.4393 - val_recall_1: 0.0000e+00
# Epoch 2/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4476 - recall_1: 0.0149 - val_loss: 0.4335 - val_recall_1: 0.0164
# Epoch 3/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4405 - recall_1: 0.1357 - val_loss: 0.4268 - val_recall_1: 0.2164
# Epoch 4/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4324 - recall_1: 0.1966 - val_loss: 0.4207 - val_recall_1: 0.3016
# Epoch 5/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4281 - recall_1: 0.2475 - val_loss: 0.4146 - val_recall_1: 0.3049
# Epoch 6/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4240 - recall_1: 0.2802 - val_loss: 0.4079 - val_recall_1: 0.2820
# Epoch 7/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4170 - recall_1: 0.2741 - val_loss: 0.4052 - val_recall_1: 0.2885
# Epoch 8/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4139 - recall_1: 0.2765 - val_loss: 0.4026 - val_recall_1: 0.2852
# Epoch 9/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4094 - recall_1: 0.2918 - val_loss: 0.3981 - val_recall_1: 0.3311
# Epoch 10/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.4113 - recall_1: 0.3249 - val_loss: 0.3947 - val_recall_1: 0.3279
# Epoch 11/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4081 - recall_1: 0.3148 - val_loss: 0.3911 - val_recall_1: 0.3344
# Epoch 12/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4084 - recall_1: 0.3182 - val_loss: 0.3913 - val_recall_1: 0.3410
# Epoch 13/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4005 - recall_1: 0.3404 - val_loss: 0.3863 - val_recall_1: 0.3639
# Epoch 14/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3977 - recall_1: 0.3234 - val_loss: 0.3803 - val_recall_1: 0.3836
# Epoch 15/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3943 - recall_1: 0.3549 - val_loss: 0.3777 - val_recall_1: 0.3705
# Epoch 16/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3894 - recall_1: 0.3677 - val_loss: 0.3712 - val_recall_1: 0.4098
# Epoch 17/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3806 - recall_1: 0.3829 - val_loss: 0.3688 - val_recall_1: 0.4131
# Epoch 18/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3808 - recall_1: 0.3667 - val_loss: 0.3631 - val_recall_1: 0.4328
# Epoch 19/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3837 - recall_1: 0.3690 - val_loss: 0.3609 - val_recall_1: 0.4328
# Epoch 20/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3780 - recall_1: 0.3902 - val_loss: 0.3602 - val_recall_1: 0.4361
# Epoch 21/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3737 - recall_1: 0.3826 - val_loss: 0.3501 - val_recall_1: 0.4590
# Epoch 22/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3794 - recall_1: 0.3818 - val_loss: 0.3498 - val_recall_1: 0.4525
# Epoch 23/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3692 - recall_1: 0.4071 - val_loss: 0.3438 - val_recall_1: 0.4787
# Epoch 24/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3722 - recall_1: 0.3879 - val_loss: 0.3428 - val_recall_1: 0.4787
# Epoch 25/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3718 - recall_1: 0.4084 - val_loss: 0.3428 - val_recall_1: 0.4459
# Epoch 26/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3661 - recall_1: 0.3959 - val_loss: 0.3416 - val_recall_1: 0.4623
# Epoch 27/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3559 - recall_1: 0.4261 - val_loss: 0.3430 - val_recall_1: 0.4623
# Epoch 28/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3668 - recall_1: 0.4070 - val_loss: 0.3404 - val_recall_1: 0.4689
# Epoch 29/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3652 - recall_1: 0.4089 - val_loss: 0.3396 - val_recall_1: 0.4787
# Epoch 30/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3645 - recall_1: 0.3815 - val_loss: 0.3397 - val_recall_1: 0.4852
# Epoch 31/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3557 - recall_1: 0.4266 - val_loss: 0.3367 - val_recall_1: 0.4754
# Epoch 32/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3574 - recall_1: 0.4152 - val_loss: 0.3377 - val_recall_1: 0.4820
# Epoch 33/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3577 - recall_1: 0.4127 - val_loss: 0.3379 - val_recall_1: 0.4820
# Epoch 34/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3614 - recall_1: 0.4084 - val_loss: 0.3389 - val_recall_1: 0.4787
# Epoch 35/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3535 - recall_1: 0.4271 - val_loss: 0.3357 - val_recall_1: 0.5016
# Epoch 36/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3554 - recall_1: 0.4067 - val_loss: 0.3395 - val_recall_1: 0.4656
# Epoch 37/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3497 - recall_1: 0.4089 - val_loss: 0.3377 - val_recall_1: 0.4689
# Epoch 38/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3506 - recall_1: 0.4425 - val_loss: 0.3352 - val_recall_1: 0.4754
# Epoch 39/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3519 - recall_1: 0.4165 - val_loss: 0.3369 - val_recall_1: 0.4852
# Epoch 40/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3556 - recall_1: 0.4239 - val_loss: 0.3367 - val_recall_1: 0.4656
# Epoch 41/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3553 - recall_1: 0.4142 - val_loss: 0.3376 - val_recall_1: 0.4754
# Epoch 42/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3461 - recall_1: 0.4288 - val_loss: 0.3332 - val_recall_1: 0.4754
# Epoch 43/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3456 - recall_1: 0.4322 - val_loss: 0.3345 - val_recall_1: 0.4820
# Epoch 44/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3505 - recall_1: 0.4265 - val_loss: 0.3373 - val_recall_1: 0.4820
# Epoch 45/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3530 - recall_1: 0.4084 - val_loss: 0.3376 - val_recall_1: 0.4557
# Epoch 46/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3462 - recall_1: 0.4237 - val_loss: 0.3378 - val_recall_1: 0.4525
# Epoch 47/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3467 - recall_1: 0.4131 - val_loss: 0.3351 - val_recall_1: 0.4689
# Epoch 48/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3466 - recall_1: 0.4147 - val_loss: 0.3377 - val_recall_1: 0.4557
# Epoch 49/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3449 - recall_1: 0.4313 - val_loss: 0.3358 - val_recall_1: 0.4623
# Epoch 50/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3447 - recall_1: 0.4295 - val_loss: 0.3355 - val_recall_1: 0.4623
# Epoch 51/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3466 - recall_1: 0.4332 - val_loss: 0.3374 - val_recall_1: 0.4754
# Epoch 52/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3472 - recall_1: 0.4295 - val_loss: 0.3355 - val_recall_1: 0.4787
# Epoch 53/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3474 - recall_1: 0.4260 - val_loss: 0.3350 - val_recall_1: 0.4787
# Epoch 54/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3522 - recall_1: 0.4223 - val_loss: 0.3379 - val_recall_1: 0.4689
# Epoch 55/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3445 - recall_1: 0.4282 - val_loss: 0.3390 - val_recall_1: 0.4689
# Epoch 56/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3420 - recall_1: 0.4329 - val_loss: 0.3377 - val_recall_1: 0.4852
# Epoch 57/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3378 - recall_1: 0.4383 - val_loss: 0.3364 - val_recall_1: 0.4590
# Epoch 58/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3451 - recall_1: 0.4196 - val_loss: 0.3352 - val_recall_1: 0.4689
# Epoch 59/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3432 - recall_1: 0.4415 - val_loss: 0.3356 - val_recall_1: 0.4787
# Epoch 60/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3487 - recall_1: 0.4301 - val_loss: 0.3379 - val_recall_1: 0.4820
# Epoch 61/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3327 - recall_1: 0.4595 - val_loss: 0.3361 - val_recall_1: 0.4852
# Epoch 62/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.3449 - recall_1: 0.4344 - val_loss: 0.3361 - val_recall_1: 0.4984
# Epoch 63/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - loss: 0.3429 - recall_1: 0.4439 - val_loss: 0.3343 - val_recall_1: 0.4787
# Epoch 64/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 3s 11ms/step - loss: 0.3400 - recall_1: 0.4440 - val_loss: 0.3346 - val_recall_1: 0.4721
# Epoch 65/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.3416 - recall_1: 0.4379 - val_loss: 0.3362 - val_recall_1: 0.4918
# Epoch 66/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 10ms/step - loss: 0.3451 - recall_1: 0.4359 - val_loss: 0.3348 - val_recall_1: 0.4656
# Epoch 67/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.3367 - recall_1: 0.4350 - val_loss: 0.3348 - val_recall_1: 0.4623
# Epoch 68/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3342 - recall_1: 0.4372 - val_loss: 0.3324 - val_recall_1: 0.4721
# Epoch 69/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3393 - recall_1: 0.4347 - val_loss: 0.3345 - val_recall_1: 0.4426
# Epoch 70/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3365 - recall_1: 0.4294 - val_loss: 0.3329 - val_recall_1: 0.4820
# Epoch 71/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3367 - recall_1: 0.4493 - val_loss: 0.3354 - val_recall_1: 0.4820
# Epoch 72/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3401 - recall_1: 0.4483 - val_loss: 0.3343 - val_recall_1: 0.4852
# Epoch 73/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3401 - recall_1: 0.4290 - val_loss: 0.3366 - val_recall_1: 0.4754
# Epoch 74/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3368 - recall_1: 0.4369 - val_loss: 0.3332 - val_recall_1: 0.4852
# Epoch 75/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3402 - recall_1: 0.4341 - val_loss: 0.3320 - val_recall_1: 0.4787
# Epoch 76/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3376 - recall_1: 0.4459 - val_loss: 0.3325 - val_recall_1: 0.4852
# Epoch 77/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3364 - recall_1: 0.4717 - val_loss: 0.3335 - val_recall_1: 0.4951
# Epoch 78/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3396 - recall_1: 0.4371 - val_loss: 0.3342 - val_recall_1: 0.4689
# Epoch 79/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3388 - recall_1: 0.4358 - val_loss: 0.3343 - val_recall_1: 0.4721
# Epoch 80/80
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - loss: 0.3365 - recall_1: 0.4273 - val_loss: 0.3371 - val_recall_1: 0.4787

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_2.history['loss'])
plt.plot(history_2.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %% [markdown]
# From the above plot, we can observe that the train and validation curves are having smooth lines. Reducing the number of neurons and adding dropouts to the model worked, and the problem of overfitting was solved.

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_2.history['recall_1'])
plt.plot(history_2.history['val_recall_1'])
plt.title('model recall')
plt.ylabel('recall')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Predicting the results using best as a threshold
y_train_pred = model_2.predict(X_train)
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 219/219 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
#Predicting the results using 0.5 as the threshold.
y_val_pred = model_2.predict(X_val)
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [False],
#        [False],
#        [False]])

# %%
model_name = "NN with Adam & Dropout"

train_metric_df.loc[model_name] = recall_score(y_train,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
#classification report
cr=classification_report(y_train,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      5574
#            1       0.83      0.48      0.60      1426
#
#     accuracy                           0.87      7000
#    macro avg       0.85      0.73      0.76      7000
# weighted avg       0.87      0.87      0.86      7000

# %%
#classification report
cr = classification_report(y_val,y_val_pred) ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.97      0.92      1195
#            1       0.80      0.48      0.60       305
#
#     accuracy                           0.87      1500
#    macro avg       0.84      0.72      0.76      1500
# weighted avg       0.86      0.87      0.86      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE) and SGD Optimizer

# %% [markdown]
# **Let's try to apply SMOTE to balance this dataset and then again apply hyperparamter tuning accordingly.**

# %%
sm  = SMOTE(random_state=42)
#Complete the code to fit SMOTE on the training data.
X_train_smote, y_train_smote= sm.fit_resample(X_train,y_train)
print('After UpSampling, the shape of train_X: {}'.format(X_train_smote.shape))
print('After UpSampling, the shape of train_y: {} \n'.format(y_train_smote.shape))
# Out:
# After UpSampling, the shape of train_X: (11148, 11)
# After UpSampling, the shape of train_y: (11148,)

# %% [markdown]
# Let's build a model with the balanced dataset

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the model
model_3 = Sequential()
#Complete the code to add a input layer (specify the # of neurons and activation function)
model_3.add(Dense(32,activation='relu',input_dim = X_train_smote.shape[1]))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_3.add(Dense(16,activation='relu'))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_3.add(Dense(8,activation='relu'))
# Complete the code to add the required number of neurons in the output layer with a sigmoid activation function.
model_3.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use SGD as the optimizer.
optimizer = tf.keras.optimizers.SGD(0.001)

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_3.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_3.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 32)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,057 (4.13 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Fitting the ANN
history_3 = model_3.fit(
    X_train_smote, y_train_smote,
    batch_size=32, ## Complete the code to specify the batch size to use
    epochs=50, ## Complete the code to specify the number of epochs
    verbose=1,
    validation_data = (X_val,y_val)
)
# Out:
# Epoch 1/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.7026 - recall: 0.9436 - val_loss: 0.7348 - val_recall: 0.9443
# Epoch 2/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6986 - recall: 0.9296 - val_loss: 0.7242 - val_recall: 0.9279
# Epoch 3/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - loss: 0.6953 - recall: 0.9117 - val_loss: 0.7147 - val_recall: 0.8918
# Epoch 4/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6921 - recall: 0.8745 - val_loss: 0.7046 - val_recall: 0.8426
# Epoch 5/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.6880 - recall: 0.8066 - val_loss: 0.6917 - val_recall: 0.7869
# Epoch 6/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6824 - recall: 0.7320 - val_loss: 0.6789 - val_recall: 0.7279
# Epoch 7/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.6770 - recall: 0.6903 - val_loss: 0.6683 - val_recall: 0.6984
# Epoch 8/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.6721 - recall: 0.6654 - val_loss: 0.6592 - val_recall: 0.6754
# Epoch 9/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6674 - recall: 0.6582 - val_loss: 0.6509 - val_recall: 0.6656
# Epoch 10/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.6627 - recall: 0.6492 - val_loss: 0.6433 - val_recall: 0.6492
# Epoch 11/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6580 - recall: 0.6427 - val_loss: 0.6364 - val_recall: 0.6361
# Epoch 12/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.6533 - recall: 0.6414 - val_loss: 0.6302 - val_recall: 0.6328
# Epoch 13/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.6487 - recall: 0.6375 - val_loss: 0.6248 - val_recall: 0.6295
# Epoch 14/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.6441 - recall: 0.6390 - val_loss: 0.6198 - val_recall: 0.6230
# Epoch 15/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6393 - recall: 0.6436 - val_loss: 0.6155 - val_recall: 0.6262
# Epoch 16/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6346 - recall: 0.6479 - val_loss: 0.6115 - val_recall: 0.6262
# Epoch 17/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6298 - recall: 0.6521 - val_loss: 0.6081 - val_recall: 0.6262
# Epoch 18/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6249 - recall: 0.6574 - val_loss: 0.6049 - val_recall: 0.6361
# Epoch 19/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6200 - recall: 0.6628 - val_loss: 0.6018 - val_recall: 0.6361
# Epoch 20/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6150 - recall: 0.6698 - val_loss: 0.5992 - val_recall: 0.6393
# Epoch 21/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6101 - recall: 0.6786 - val_loss: 0.5967 - val_recall: 0.6426
# Epoch 22/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6053 - recall: 0.6859 - val_loss: 0.5943 - val_recall: 0.6393
# Epoch 23/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.6006 - recall: 0.6952 - val_loss: 0.5920 - val_recall: 0.6393
# Epoch 24/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5960 - recall: 0.7006 - val_loss: 0.5899 - val_recall: 0.6328
# Epoch 25/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5916 - recall: 0.7018 - val_loss: 0.5879 - val_recall: 0.6328
# Epoch 26/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5875 - recall: 0.7036 - val_loss: 0.5861 - val_recall: 0.6361
# Epoch 27/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5836 - recall: 0.7072 - val_loss: 0.5847 - val_recall: 0.6426
# Epoch 28/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5799 - recall: 0.7108 - val_loss: 0.5833 - val_recall: 0.6492
# Epoch 29/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5765 - recall: 0.7106 - val_loss: 0.5821 - val_recall: 0.6525
# Epoch 30/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5735 - recall: 0.7163 - val_loss: 0.5807 - val_recall: 0.6590
# Epoch 31/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5707 - recall: 0.7190 - val_loss: 0.5795 - val_recall: 0.6590
# Epoch 32/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5682 - recall: 0.7218 - val_loss: 0.5788 - val_recall: 0.6689
# Epoch 33/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5660 - recall: 0.7232 - val_loss: 0.5779 - val_recall: 0.6689
# Epoch 34/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5640 - recall: 0.7252 - val_loss: 0.5772 - val_recall: 0.6787
# Epoch 35/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.5622 - recall: 0.7254 - val_loss: 0.5769 - val_recall: 0.6721
# Epoch 36/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.5606 - recall: 0.7266 - val_loss: 0.5764 - val_recall: 0.6721
# Epoch 37/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5591 - recall: 0.7289 - val_loss: 0.5762 - val_recall: 0.6721
# Epoch 38/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5578 - recall: 0.7294 - val_loss: 0.5757 - val_recall: 0.6754
# Epoch 39/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5566 - recall: 0.7313 - val_loss: 0.5754 - val_recall: 0.6754
# Epoch 40/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5555 - recall: 0.7354 - val_loss: 0.5751 - val_recall: 0.6787
# Epoch 41/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5545 - recall: 0.7367 - val_loss: 0.5748 - val_recall: 0.6787
# Epoch 42/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5535 - recall: 0.7365 - val_loss: 0.5745 - val_recall: 0.6787
# Epoch 43/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5526 - recall: 0.7381 - val_loss: 0.5741 - val_recall: 0.6820
# Epoch 44/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5518 - recall: 0.7408 - val_loss: 0.5738 - val_recall: 0.6820
# Epoch 45/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5510 - recall: 0.7406 - val_loss: 0.5735 - val_recall: 0.6787
# Epoch 46/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5503 - recall: 0.7407 - val_loss: 0.5732 - val_recall: 0.6820
# Epoch 47/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5496 - recall: 0.7430 - val_loss: 0.5731 - val_recall: 0.6918
# Epoch 48/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5489 - recall: 0.7438 - val_loss: 0.5730 - val_recall: 0.6918
# Epoch 49/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5483 - recall: 0.7439 - val_loss: 0.5728 - val_recall: 0.6918
# Epoch 50/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.5477 - recall: 0.7460 - val_loss: 0.5724 - val_recall: 0.6918

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_3.history['loss'])
plt.plot(history_3.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_3.history['recall'])
plt.plot(history_3.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
y_train_pred = model_3.predict(X_train_smote)
#Predicting the results using 0.5 as the threshold
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 1ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [False]])

# %%
y_val_pred = model_3.predict(X_val)
#Predicting the results using 0.5 as the threshold
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
model_name = "NN with SMOTE & SGD"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
cr=classification_report(y_train_smote,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.74      0.73      0.73      5574
#            1       0.73      0.75      0.74      5574
#
#     accuracy                           0.74     11148
#    macro avg       0.74      0.74      0.74     11148
# weighted avg       0.74      0.74      0.74     11148

# %%
cr=classification_report(y_val,y_val_pred) ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.90      0.71      0.80      1195
#            1       0.38      0.69      0.49       305
#
#     accuracy                           0.71      1500
#    macro avg       0.64      0.70      0.64      1500
# weighted avg       0.79      0.71      0.73      1500

# %% [markdown]
# The use of SMOTE significantly improved recall for the minority class (churners), especially on the validation set (0.69 vs. previous ~0.50).
# Balanced performance on the training set indicates the model successfully learned from the SMOTE-balanced data. Precision for churners on the validation set is low (0.38), leading to many false positives. This suggests that while SMOTE improves recall, it increases the risk of over-predicting churners.

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train_smote, y_train_pred)

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE) and Adam Optimizer
# ---

# %% [markdown]
# Let's build a model with the balanced dataset

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the model
model_4 = Sequential()
#Complete the code to add a input layer (specify the # of neurons and activation function)
model_4.add(Dense(32,activation='relu',input_dim = X_train_smote.shape[1]))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_4.add(Dense(16,activation='relu'))
#Complete the code to add a hidden layer (specify the # of neurons and activation function)
model_4.add(Dense(8,activation='relu'))
# Complete the code to add the required number of neurons in the output layer and a suitable activation function.
model_4.add(Dense(1, activation = 'sigmoid'))

# %%
model_4.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 32)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,057 (4.13 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam()

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_4.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_4.summary()
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense_1 (Dense)                      │ (None, 32)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_4 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,057 (4.13 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
#Fitting the ANN

history_4 = model_4.fit(
    X_train_smote,y_train_smote,
    batch_size=32, ## Complete the code to specify the batch size to use
    epochs=50,  ## Complete the code to specify the number of epochs
    verbose=1,
    validation_data = (X_val,y_val)
)
# Out:
# Epoch 1/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 7s 11ms/step - loss: 0.6278 - recall: 0.7269 - val_loss: 0.5477 - val_recall: 0.6557
# Epoch 2/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5376 - recall: 0.7538 - val_loss: 0.5368 - val_recall: 0.6590
# Epoch 3/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.5135 - recall: 0.7720 - val_loss: 0.5145 - val_recall: 0.6689
# Epoch 4/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4842 - recall: 0.7930 - val_loss: 0.4900 - val_recall: 0.6885
# Epoch 5/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4649 - recall: 0.7943 - val_loss: 0.4776 - val_recall: 0.7016
# Epoch 6/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4510 - recall: 0.8050 - val_loss: 0.4671 - val_recall: 0.7082
# Epoch 7/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4410 - recall: 0.8080 - val_loss: 0.4589 - val_recall: 0.7148
# Epoch 8/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4327 - recall: 0.8145 - val_loss: 0.4499 - val_recall: 0.7082
# Epoch 9/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4260 - recall: 0.8153 - val_loss: 0.4471 - val_recall: 0.7082
# Epoch 10/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4206 - recall: 0.8167 - val_loss: 0.4433 - val_recall: 0.7049
# Epoch 11/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.4157 - recall: 0.8197 - val_loss: 0.4383 - val_recall: 0.7016
# Epoch 12/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4115 - recall: 0.8207 - val_loss: 0.4360 - val_recall: 0.7049
# Epoch 13/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4079 - recall: 0.8192 - val_loss: 0.4338 - val_recall: 0.7016
# Epoch 14/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4046 - recall: 0.8199 - val_loss: 0.4302 - val_recall: 0.6885
# Epoch 15/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4019 - recall: 0.8196 - val_loss: 0.4307 - val_recall: 0.6951
# Epoch 16/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3994 - recall: 0.8223 - val_loss: 0.4278 - val_recall: 0.6885
# Epoch 17/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3973 - recall: 0.8234 - val_loss: 0.4262 - val_recall: 0.6787
# Epoch 18/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3952 - recall: 0.8214 - val_loss: 0.4263 - val_recall: 0.6852
# Epoch 19/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3933 - recall: 0.8229 - val_loss: 0.4272 - val_recall: 0.6852
# Epoch 20/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3912 - recall: 0.8250 - val_loss: 0.4249 - val_recall: 0.6787
# Epoch 21/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.3892 - recall: 0.8222 - val_loss: 0.4251 - val_recall: 0.6787
# Epoch 22/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 4ms/step - loss: 0.3875 - recall: 0.8222 - val_loss: 0.4219 - val_recall: 0.6656
# Epoch 23/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3858 - recall: 0.8249 - val_loss: 0.4197 - val_recall: 0.6656
# Epoch 24/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3837 - recall: 0.8254 - val_loss: 0.4184 - val_recall: 0.6689
# Epoch 25/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3821 - recall: 0.8261 - val_loss: 0.4160 - val_recall: 0.6689
# Epoch 26/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3803 - recall: 0.8253 - val_loss: 0.4144 - val_recall: 0.6721
# Epoch 27/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3785 - recall: 0.8269 - val_loss: 0.4136 - val_recall: 0.6721
# Epoch 28/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3771 - recall: 0.8260 - val_loss: 0.4134 - val_recall: 0.6754
# Epoch 29/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3758 - recall: 0.8266 - val_loss: 0.4130 - val_recall: 0.6689
# Epoch 30/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3743 - recall: 0.8287 - val_loss: 0.4123 - val_recall: 0.6689
# Epoch 31/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.3730 - recall: 0.8279 - val_loss: 0.4119 - val_recall: 0.6689
# Epoch 32/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.3715 - recall: 0.8318 - val_loss: 0.4122 - val_recall: 0.6656
# Epoch 33/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3705 - recall: 0.8340 - val_loss: 0.4119 - val_recall: 0.6623
# Epoch 34/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3691 - recall: 0.8333 - val_loss: 0.4119 - val_recall: 0.6656
# Epoch 35/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3677 - recall: 0.8343 - val_loss: 0.4125 - val_recall: 0.6656
# Epoch 36/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.3665 - recall: 0.8356 - val_loss: 0.4123 - val_recall: 0.6623
# Epoch 37/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3654 - recall: 0.8360 - val_loss: 0.4128 - val_recall: 0.6656
# Epoch 38/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3641 - recall: 0.8372 - val_loss: 0.4142 - val_recall: 0.6623
# Epoch 39/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3625 - recall: 0.8368 - val_loss: 0.4143 - val_recall: 0.6623
# Epoch 40/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3614 - recall: 0.8386 - val_loss: 0.4153 - val_recall: 0.6590
# Epoch 41/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.3600 - recall: 0.8384 - val_loss: 0.4173 - val_recall: 0.6721
# Epoch 42/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.3589 - recall: 0.8384 - val_loss: 0.4170 - val_recall: 0.6689
# Epoch 43/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 2ms/step - loss: 0.3576 - recall: 0.8397 - val_loss: 0.4178 - val_recall: 0.6721
# Epoch 44/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3564 - recall: 0.8408 - val_loss: 0.4168 - val_recall: 0.6656
# Epoch 45/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3553 - recall: 0.8397 - val_loss: 0.4182 - val_recall: 0.6623
# Epoch 46/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3542 - recall: 0.8418 - val_loss: 0.4183 - val_recall: 0.6557
# Epoch 47/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3532 - recall: 0.8458 - val_loss: 0.4194 - val_recall: 0.6590
# Epoch 48/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3520 - recall: 0.8455 - val_loss: 0.4184 - val_recall: 0.6557
# Epoch 49/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3510 - recall: 0.8473 - val_loss: 0.4183 - val_recall: 0.6590
# Epoch 50/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.3500 - recall: 0.8478 - val_loss: 0.4185 - val_recall: 0.6492

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_4.history['loss'])
plt.plot(history_4.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_4.history['recall'])
plt.plot(history_4.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
y_train_pred = model_4.predict(X_train_smote)
#Predicting the results using 0.5 as the threshold
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [ True]])

# %%
y_val_pred = model_4.predict(X_val)
#Predicting the results using 0.5 as the threshold
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
model_name = "NN with SMOTE & Adam"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
cr=classification_report(y_train_smote,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.84      0.87      0.86      5574
#            1       0.87      0.83      0.85      5574
#
#     accuracy                           0.85     11148
#    macro avg       0.85      0.85      0.85     11148
# weighted avg       0.85      0.85      0.85     11148

# %%
cr=classification_report(y_val,y_val_pred) ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.91      0.86      0.88      1195
#            1       0.54      0.65      0.59       305
#
#     accuracy                           0.82      1500
#    macro avg       0.72      0.75      0.74      1500
# weighted avg       0.83      0.82      0.82      1500

# %% [markdown]
# Model 3:
#
# Generalizes better with less overfitting.
# Suitable if you prioritize recall for churners (catching most churners even at the cost of more false positives).
#
# Model 4:
#
# Learns the training data more effectively but overfits more to it.
# Suitable if you prioritize precision (fewer false positives) while still maintaining decent recall.
#
# If the priority is identifying all churners: Model 3 is better due to its higher recall for churners.
#
#
# If the priority is reducing false positives: Model 4 is better because of its higher precision and balanced F1-score.

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train_smote, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# #Calculating the confusion matrix
#
# make_confusion_matrix(____,____) ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ### Neural Network with Balanced Data (by applying SMOTE), Adam Optimizer, and Dropout

# %%
backend.clear_session()
#Fixing the seed for random number generators so that we can ensure we receive the same output everytime
np.random.seed(2)
random.seed(2)
tf.random.set_seed(2)

# %%
#Initializing the model
model_5 = Sequential()
# Complete the code to add required # of neurons to the input layer with relu as activation function
model_5.add(Dense(32,activation='relu',input_dim = X_train_smote.shape[1]))
#Complete the code to add dropout rate
model_5.add(Dropout(0.2))
# Complete the code to add required # neurons to the hidden layer with any activation function.
model_5.add(Dense(16,activation='relu'))
# Complete the code to add dropout rate.
model_5.add(Dropout(0.1))
# Adding hidden layer with 8 neurons with relu as activation function
model_5.add(Dense(8,activation='relu'))
# Complete the code to add the required number of neurons in the output layer with a suitable activation function.
model_5.add(Dense(1, activation = 'sigmoid'))

# %%
#Complete the code to use Adam as the optimizer.
optimizer = tf.keras.optimizers.Adam()

# uncomment one of the following lines to define the metric to be used
# metric = 'accuracy'
metric = keras.metrics.Recall()
# metric = keras.metrics.Precision()
# metric = keras.metrics.F1Score()

# %%
# Complete the code to compile the model with binary cross entropy as loss function and recall as the metric
model_5.compile(loss='binary_crossentropy',optimizer=optimizer,metrics=[metric])

# %%
model_5.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 32)                  │             384 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 32)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 16)                  │             528 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout_1 (Dropout)                  │ (None, 16)                  │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 8)                   │             136 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               9 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 1,057 (4.13 KB)
#  Trainable params: 1,057 (4.13 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
history_5 = model_5.fit(
    X_train_smote,y_train_smote,
    batch_size=32, ## Complete the code to specify the batch size to use
    epochs= 50, ## Complete the code to specify the number of epochs
    verbose=1,
    validation_data = (X_val,y_val))
# Out:
# Epoch 1/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - loss: 0.6313 - recall: 0.6209 - val_loss: 0.5225 - val_recall: 0.6164
# Epoch 2/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 4s 5ms/step - loss: 0.5566 - recall: 0.7355 - val_loss: 0.5116 - val_recall: 0.6361
# Epoch 3/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.5367 - recall: 0.7492 - val_loss: 0.5064 - val_recall: 0.6492
# Epoch 4/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.5219 - recall: 0.7485 - val_loss: 0.4884 - val_recall: 0.6328
# Epoch 5/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.5072 - recall: 0.7455 - val_loss: 0.4893 - val_recall: 0.6492
# Epoch 6/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4961 - recall: 0.7523 - val_loss: 0.4842 - val_recall: 0.6525
# Epoch 7/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4881 - recall: 0.7592 - val_loss: 0.4757 - val_recall: 0.6623
# Epoch 8/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4796 - recall: 0.7547 - val_loss: 0.4625 - val_recall: 0.6459
# Epoch 9/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4745 - recall: 0.7595 - val_loss: 0.4596 - val_recall: 0.6721
# Epoch 10/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4692 - recall: 0.7631 - val_loss: 0.4483 - val_recall: 0.6787
# Epoch 11/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4590 - recall: 0.7783 - val_loss: 0.4498 - val_recall: 0.6820
# Epoch 12/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4631 - recall: 0.7682 - val_loss: 0.4413 - val_recall: 0.6852
# Epoch 13/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 3ms/step - loss: 0.4551 - recall: 0.7690 - val_loss: 0.4360 - val_recall: 0.6918
# Epoch 14/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4497 - recall: 0.7726 - val_loss: 0.4353 - val_recall: 0.6984
# Epoch 15/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4442 - recall: 0.7844 - val_loss: 0.4320 - val_recall: 0.6984
# Epoch 16/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4339 - recall: 0.7828 - val_loss: 0.4279 - val_recall: 0.7082
# Epoch 17/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4353 - recall: 0.7855 - val_loss: 0.4177 - val_recall: 0.6951
# Epoch 18/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.4359 - recall: 0.7765 - val_loss: 0.4209 - val_recall: 0.7016
# Epoch 19/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4335 - recall: 0.7837 - val_loss: 0.4171 - val_recall: 0.6918
# Epoch 20/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4317 - recall: 0.7887 - val_loss: 0.4276 - val_recall: 0.7213
# Epoch 21/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4284 - recall: 0.7961 - val_loss: 0.4157 - val_recall: 0.7016
# Epoch 22/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4281 - recall: 0.7990 - val_loss: 0.4195 - val_recall: 0.7115
# Epoch 23/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4313 - recall: 0.7865 - val_loss: 0.4177 - val_recall: 0.7148
# Epoch 24/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4277 - recall: 0.8005 - val_loss: 0.4251 - val_recall: 0.7213
# Epoch 25/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4241 - recall: 0.7961 - val_loss: 0.4107 - val_recall: 0.7082
# Epoch 26/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4271 - recall: 0.7988 - val_loss: 0.4161 - val_recall: 0.7213
# Epoch 27/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4235 - recall: 0.8068 - val_loss: 0.4117 - val_recall: 0.7082
# Epoch 28/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4227 - recall: 0.7952 - val_loss: 0.4135 - val_recall: 0.7180
# Epoch 29/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4204 - recall: 0.8013 - val_loss: 0.4119 - val_recall: 0.7049
# Epoch 30/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4206 - recall: 0.7928 - val_loss: 0.4193 - val_recall: 0.7180
# Epoch 31/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 4ms/step - loss: 0.4210 - recall: 0.8011 - val_loss: 0.4154 - val_recall: 0.7148
# Epoch 32/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4155 - recall: 0.8046 - val_loss: 0.4109 - val_recall: 0.7180
# Epoch 33/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4184 - recall: 0.8046 - val_loss: 0.4182 - val_recall: 0.7213
# Epoch 34/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4184 - recall: 0.8025 - val_loss: 0.4116 - val_recall: 0.7049
# Epoch 35/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4207 - recall: 0.8010 - val_loss: 0.4102 - val_recall: 0.7115
# Epoch 36/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - loss: 0.4173 - recall: 0.7980 - val_loss: 0.4130 - val_recall: 0.7115
# Epoch 37/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4165 - recall: 0.8067 - val_loss: 0.4123 - val_recall: 0.7082
# Epoch 38/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 3s 5ms/step - loss: 0.4179 - recall: 0.8092 - val_loss: 0.4177 - val_recall: 0.7213
# Epoch 39/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4116 - recall: 0.8203 - val_loss: 0.4042 - val_recall: 0.6984
# Epoch 40/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4174 - recall: 0.8089 - val_loss: 0.4099 - val_recall: 0.7180
# Epoch 41/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4198 - recall: 0.8023 - val_loss: 0.4113 - val_recall: 0.7148
# Epoch 42/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4154 - recall: 0.8034 - val_loss: 0.4121 - val_recall: 0.7115
# Epoch 43/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4132 - recall: 0.8063 - val_loss: 0.4132 - val_recall: 0.7148
# Epoch 44/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4165 - recall: 0.8084 - val_loss: 0.4093 - val_recall: 0.7115
# Epoch 45/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step - loss: 0.4142 - recall: 0.8061 - val_loss: 0.4131 - val_recall: 0.7082
# Epoch 46/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4161 - recall: 0.8180 - val_loss: 0.4096 - val_recall: 0.7115
# Epoch 47/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 4ms/step - loss: 0.4115 - recall: 0.8187 - val_loss: 0.4123 - val_recall: 0.7213
# Epoch 48/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 5ms/step - loss: 0.4056 - recall: 0.8183 - val_loss: 0.4075 - val_recall: 0.6984
# Epoch 49/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 2s 3ms/step - loss: 0.4117 - recall: 0.8136 - val_loss: 0.4069 - val_recall: 0.7049
# Epoch 50/50
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 3ms/step - loss: 0.4102 - recall: 0.8158 - val_loss: 0.4120 - val_recall: 0.7082

# %% [markdown]
# **Loss function**

# %%
#Plotting Train Loss vs Validation Loss
plt.plot(history_5.history['loss'])
plt.plot(history_5.history['val_loss'])
plt.title('model loss')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
#Plotting Train recall vs Validation recall
plt.plot(history_5.history['recall'])
plt.plot(history_5.history['val_recall'])
plt.title('model recall')
plt.ylabel('Loss')
plt.xlabel('Epoch')
plt.legend(['train', 'validation'], loc='upper left')
plt.show()

# %%
y_train_pred = model_5.predict(X_train_smote)
#Predicting the results using 0.5 as the threshold
y_train_pred = (y_train_pred > 0.5)
y_train_pred
# Out:
# 349/349 ━━━━━━━━━━━━━━━━━━━━ 1s 2ms/step
# array([[ True],
#        [False],
#        [False],
#        ...,
#        [False],
#        [ True],
#        [ True]])

# %%
y_val_pred = model_5.predict(X_val)
#Predicting the results using 0.5 as the threshold
y_val_pred = (y_val_pred > 0.5)
y_val_pred
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 1ms/step
# array([[False],
#        [False],
#        [False],
#        ...,
#        [ True],
#        [False],
#        [False]])

# %%
model_name = "NN with SMOTE,Adam & Dropout"

train_metric_df.loc[model_name] = recall_score(y_train_smote,y_train_pred)
valid_metric_df.loc[model_name] = recall_score(y_val,y_val_pred)

# %% [markdown]
# **Classification report**

# %%
cr=classification_report(y_train_smote,y_train_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.83      0.84      0.83      5574
#            1       0.84      0.82      0.83      5574
#
#     accuracy                           0.83     11148
#    macro avg       0.83      0.83      0.83     11148
# weighted avg       0.83      0.83      0.83     11148

# %%
#classification report
cr=classification_report(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87      1195
#            1       0.52      0.71      0.60       305
#
#     accuracy                           0.81      1500
#    macro avg       0.72      0.77      0.74      1500
# weighted avg       0.84      0.81      0.82      1500

# %% [markdown]
# **Confusion matrix**

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_train_smote, y_train_pred)

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_val,y_val_pred)  ## Complete the code to check the model's performance on the validation set

# %% [markdown]
# ## Model Performance Comparison and Final Model Selection

# %%
print("Training performance comparison")
train_metric_df
# Out:
# Training performance comparison
#                                 recall
# NN with Adam & Dropout        0.476157
# NN with SMOTE & SGD           0.747219
# NN with SMOTE & Adam          0.831898
# NN with SMOTE,Adam & Dropout  0.823466

# %%
print("Validation set performance comparison")
valid_metric_df
# Out:
# Validation set performance comparison
#                                 recall
# NN with Adam & Dropout        0.478689
# NN with SMOTE & SGD           0.691803
# NN with SMOTE & Adam          0.649180
# NN with SMOTE,Adam & Dropout  0.708197

# %%
train_metric_df - valid_metric_df
# Out:
#                                 recall
# NN with Adam & Dropout       -0.002531
# NN with SMOTE & SGD           0.055416
# NN with SMOTE & Adam          0.182718
# NN with SMOTE,Adam & Dropout  0.115269

# %%
y_test_pred = model_5.predict(X_test)    ## Complete the code to specify the best model
y_test_pred = (y_test_pred > 0.5)
print(y_test_pred)
# Out:
# 47/47 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# [[False]
#  [ True]
#  [False]
#  ...
#  [False]
#  [False]
#  [ True]]

# %%
#lets print classification report
cr=classification_report(y_test,y_test_pred)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.92      0.83      0.87      1194
#            1       0.52      0.72      0.60       306
#
#     accuracy                           0.81      1500
#    macro avg       0.72      0.77      0.74      1500
# weighted avg       0.84      0.81      0.82      1500

# %%
#Calculating the confusion matrix
make_confusion_matrix(y_test,y_test_pred)

# %% [markdown]
# ## Actionable Insights and Business Recommendations

# %% [markdown]
# *

# %% [markdown]
# <font size=6 color='blue'>Power Ahead</font>
# ___
